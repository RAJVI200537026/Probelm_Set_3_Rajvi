# %% [markdown]
# # Qusetion 1

# %%
# Step 1, 2 and 3. Import the necessary libraries , URL and assign Dataset to variable.
import pandas as pd
from tabulate import tabulate

link = "https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user"
users_Data = pd.read_csv(link, sep='|')
print(users_Data)
print(tabulate(users_Data, headers='keys', tablefmt='pretty'))
# Out:
#      user_id  age gender     occupation zip_code
# 0          1   24      M     technician    85711
# 1          2   53      F          other    94043
# 2          3   23      M         writer    32067
# 3          4   24      M     technician    43537
# 4          5   33      F          other    15213
# ..       ...  ...    ...            ...      ...
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841
#
# [943 rows x 5 columns]
# +-----+---------+-----+--------+---------------+----------+
# |     | user_id | age | gender |  occupation   | zip_code |
# +-----+---------+-----+--------+---------------+----------+
# |  0  |    1    | 24  |   M    |  technician   |  85711   |
# |  1  |    2    | 53  |   F    |     other     |  94043   |
# ...

# %%
#step 4: Discover what is the mean age per occupation
mean_age_by_occupation = users.groupby('occupation')['age'].mean()

# Convert the Series to a DataFrame for tabulate
mean_age_df = mean_age_by_occupation.reset_index()

# Print the output in a table format
print(tabulate(mean_age_df, headers='keys', tablefmt='pretty'))
# Out:
# +----+---------------+--------------------+
# |    |  occupation   |        age         |
# +----+---------------+--------------------+
# | 0  | administrator | 38.74683544303797  |
# | 1  |    artist     | 31.392857142857142 |
# | 2  |    doctor     | 43.57142857142857  |
# | 3  |   educator    | 42.01052631578948  |
# | 4  |   engineer    | 36.38805970149254  |
# | 5  | entertainment | 29.22222222222222  |
# | 6  |   executive   |      38.71875      |
# | 7  |  healthcare   |      41.5625       |
# | 8  |   homemaker   | 32.57142857142857  |
# | 9  |    lawyer     |       36.75        |
# | 10 |   librarian   |        40.0        |
# | 11 |   marketing   | 37.61538461538461  |
# | 12 |     none      | 26.555555555555557 |
# | 13 |     other     | 34.523809523809526 |
# | 14 |  programmer   | 33.121212121212125 |
# | 15 |    retired    | 63.07142857142857  |
# | 16 |   salesman    | 35.666666666666664 |
# | 17 |   scientist   | 35.54838709677419  |
# ...

# %%
#step 5: Discover the Male ratio per occupation and sort it from the most to the least
users['is_male'] = (users['gender'] == 'M').astype(int)
male_ratio_by_occupation = users.groupby('occupation')['is_male'].mean().sort_values(ascending=False)

male_ratio_df = male_ratio_by_occupation.reset_index()
print(tabulate(male_ratio_df, headers='keys', tablefmt='pretty'))
# Out:
# +----+---------------+---------------------+
# |    |  occupation   |       is_male       |
# +----+---------------+---------------------+
# | 0  |    doctor     |         1.0         |
# | 1  |   engineer    | 0.9701492537313433  |
# | 2  |  technician   | 0.9629629629629629  |
# | 3  |    retired    | 0.9285714285714286  |
# | 4  |  programmer   | 0.9090909090909091  |
# | 5  |   executive   |       0.90625       |
# | 6  |   scientist   | 0.9032258064516129  |
# | 7  | entertainment | 0.8888888888888888  |
# | 8  |    lawyer     | 0.8333333333333334  |
# | 9  |   salesman    |        0.75         |
# | 10 |   educator    | 0.7263157894736842  |
# | 11 |    student    | 0.6938775510204082  |
# | 12 |     other     | 0.6571428571428571  |
# | 13 |   marketing   | 0.6153846153846154  |
# | 14 |    writer     | 0.5777777777777777  |
# | 15 |     none      | 0.5555555555555556  |
# | 16 | administrator | 0.5443037974683544  |
# | 17 |    artist     | 0.5357142857142857  |
# ...

# %%
#Step 6:. For each occupation, calculate the minimum and maximum ages
age_range_by_occupation = users.groupby('occupation')['age'].agg(['min', 'max'])
print(tabulate(age_range_by_occupation, headers='keys', tablefmt='pretty'))
# Out:
# +---------------+-----+-----+
# |  occupation   | min | max |
# +---------------+-----+-----+
# | administrator | 21  | 70  |
# |    artist     | 19  | 48  |
# |    doctor     | 28  | 64  |
# |   educator    | 23  | 63  |
# |   engineer    | 22  | 70  |
# | entertainment | 15  | 50  |
# |   executive   | 22  | 69  |
# |  healthcare   | 22  | 62  |
# |   homemaker   | 20  | 50  |
# |    lawyer     | 21  | 53  |
# |   librarian   | 23  | 69  |
# |   marketing   | 24  | 55  |
# |     none      | 11  | 55  |
# |     other     | 13  | 64  |
# |  programmer   | 20  | 63  |
# |    retired    | 51  | 73  |
# |   salesman    | 18  | 66  |
# |   scientist   | 23  | 55  |
# |    student    |  7  | 42  |
# |  technician   | 21  | 55  |
# |    writer     | 18  | 60  |
# +---------------+-----+-----+

# %%
#step 7:. For each combination of occupation and sex, calculate the mean age 
mean_age_by_occupation_sex = users.groupby(['occupation', 'gender'])['age'].mean()
mean_age_by_occupation_sex_df = mean_age_by_occupation_sex.reset_index()
print(tabulate(mean_age_by_occupation_sex_df, headers='keys', tablefmt='pretty'))
# Out:
# +----+---------------+--------+--------------------+
# |    |  occupation   | gender |        age         |
# +----+---------------+--------+--------------------+
# | 0  | administrator |   F    | 40.638888888888886 |
# | 1  | administrator |   M    | 37.16279069767442  |
# | 2  |    artist     |   F    | 30.307692307692307 |
# | 3  |    artist     |   M    | 32.333333333333336 |
# | 4  |    doctor     |   M    | 43.57142857142857  |
# | 5  |   educator    |   F    | 39.11538461538461  |
# | 6  |   educator    |   M    | 43.10144927536232  |
# | 7  |   engineer    |   F    |        29.5        |
# | 8  |   engineer    |   M    |        36.6        |
# | 9  | entertainment |   F    |        31.0        |
# | 10 | entertainment |   M    |        29.0        |
# | 11 |   executive   |   F    |        44.0        |
# | 12 |   executive   |   M    | 38.172413793103445 |
# | 13 |  healthcare   |   F    | 39.81818181818182  |
# | 14 |  healthcare   |   M    |        45.4        |
# ...

# %%
#step 8: For each occupation present the percentage of women and men
gender_percentage_by_occupation = users.groupby(['occupation', 'gender'])['is_male'].count() / users.groupby('occupation')['is_male'].count() * 100
gender_percentage_by_occupation = gender_percentage_by_occupation.unstack()
gender_percentage_by_occupation.columns = ['Female (%)', 'Male (%)']
print(tabulate(gender_percentage_by_occupation, headers='keys', tablefmt='pretty'))
# Out:
# +---------------+--------------------+--------------------+
# |  occupation   |     Female (%)     |      Male (%)      |
# +---------------+--------------------+--------------------+
# | administrator | 45.56962025316456  | 54.43037974683544  |
# |    artist     | 46.42857142857143  | 53.57142857142857  |
# |    doctor     |        nan         |       100.0        |
# |   educator    | 27.368421052631582 | 72.63157894736842  |
# |   engineer    | 2.9850746268656714 | 97.01492537313433  |
# | entertainment | 11.11111111111111  | 88.88888888888889  |
# |   executive   |       9.375        |       90.625       |
# |  healthcare   |       68.75        |       31.25        |
# |   homemaker   | 85.71428571428571  | 14.285714285714285 |
# |    lawyer     | 16.666666666666664 | 83.33333333333334  |
# |   librarian   | 56.86274509803921  | 43.13725490196079  |
# |   marketing   | 38.46153846153847  | 61.53846153846154  |
# |     none      | 44.44444444444444  | 55.55555555555556  |
# ...

# %% [markdown]
# # Question 2

# %%
url = "https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/02_Filtering_%26_Sorting/Euro12/Euro_2012_stats_TEAM.csv"
euro12 = pd.read_csv(url)

# %%
# Step 4: Select only the Goal column
goals = euro12['Goals'] 
goals_df = goals.reset_index(drop=True).to_frame(name='Goals')
print(tabulate(goals_df, headers='keys', tablefmt='pretty'))
# Out:
# +----+-------+
# |    | Goals |
# +----+-------+
# | 0  |   4   |
# | 1  |   4   |
# | 2  |   4   |
# | 3  |   5   |
# | 4  |   3   |
# | 5  |  10   |
# | 6  |   5   |
# | 7  |   6   |
# | 8  |   2   |
# | 9  |   2   |
# | 10 |   6   |
# | 11 |   1   |
# | 12 |   5   |
# | 13 |  12   |
# | 14 |   5   |
# | 15 |   2   |
# +----+-------+

# %%
#step 5: How many team participated in the Euro2012? 
num_teams = euro12['Team'].nunique()
data = {'Number of Teams Participated in Euro2012': [num_teams]}
df = pd.DataFrame(data)
print(tabulate(df, headers='keys', tablefmt='pretty', showindex=False))
# Out:
# +------------------------------------------+
# | Number of Teams Participated in Euro2012 |
# +------------------------------------------+
# |                    16                    |
# +------------------------------------------+

# %%
#step 6:What is the number of columns in the dataset?
num_teams = euro12['Team'].nunique()
print("Number of teams participated in Euro2012:", num_teams)
# Out:
# Number of teams participated in Euro2012: 16

# %%
#step 7: View only the columns Team, Yellow Cards and Red Cards and assign them to a dataframe called discipline
discipline = euro12[['Team', 'Yellow Cards', 'Red Cards']]
print(tabulate(discipline, headers='keys', tablefmt='pretty'))
# Out:
# +----+---------------------+--------------+-----------+
# |    |        Team         | Yellow Cards | Red Cards |
# +----+---------------------+--------------+-----------+
# | 0  |       Croatia       |      9       |     0     |
# | 1  |   Czech Republic    |      7       |     0     |
# | 2  |       Denmark       |      4       |     0     |
# | 3  |       England       |      5       |     0     |
# | 4  |       France        |      6       |     0     |
# | 5  |       Germany       |      4       |     0     |
# | 6  |       Greece        |      9       |     1     |
# | 7  |        Italy        |      16      |     0     |
# | 8  |     Netherlands     |      5       |     0     |
# | 9  |       Poland        |      7       |     1     |
# | 10 |      Portugal       |      12      |     0     |
# | 11 | Republic of Ireland |      6       |     1     |
# | 12 |       Russia        |      6       |     0     |
# | 13 |        Spain        |      11      |     0     |
# ...

# %%
#step 8: Sort the teams by Red Cards, then to Yellow Cards 
sorted_discipline = discipline.sort_values(by=['Red Cards', 'Yellow Cards'], ascending=False)
print(tabulate(sorted_discipline, headers='keys', tablefmt='pretty'))
# Out:
# +----+---------------------+--------------+-----------+
# |    |        Team         | Yellow Cards | Red Cards |
# +----+---------------------+--------------+-----------+
# | 6  |       Greece        |      9       |     1     |
# | 9  |       Poland        |      7       |     1     |
# | 11 | Republic of Ireland |      6       |     1     |
# | 7  |        Italy        |      16      |     0     |
# | 10 |      Portugal       |      12      |     0     |
# | 13 |        Spain        |      11      |     0     |
# | 0  |       Croatia       |      9       |     0     |
# | 1  |   Czech Republic    |      7       |     0     |
# | 14 |       Sweden        |      7       |     0     |
# | 4  |       France        |      6       |     0     |
# | 12 |       Russia        |      6       |     0     |
# | 3  |       England       |      5       |     0     |
# | 8  |     Netherlands     |      5       |     0     |
# | 15 |       Ukraine       |      5       |     0     |
# ...

# %%
#step 9: Calculate the mean Yellow Cards given per Team
mean_yellow_cards = euro12['Yellow Cards'].mean()
print("Mean Yellow Cards given per Team:", mean_yellow_cards)
# Out:
# Mean Yellow Cards given per Team: 7.4375

# %%
#step 10:Filter teams that scored more than 6 goals
high_scoring_teams = euro12[euro12['Goals'] > 6]
print(high_scoring_teams)
# Out:
#        Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5   Germany     10               32                32             47.8%
# 13    Spain     12               42                33             55.9%
#
#    % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5             15.6%                          80             2              1
# 13            16.0%                         100             0              1
#
#     Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                      0  ...          10                 62.6%         63
# 13                     0  ...          15                 93.8%        102
#
#    Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5              49        12             4          0       15        15
# 13             83        19            11          0       17        17
#
#     Players Used
# 5             17
# 13            18
#
# ...

# %%
#Step 11. Select the teams that start with G
teams_starting_with_G = euro12[euro12['Team'].str.startswith('G')]
print(teams_starting_with_G)
# Out:
#       Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5  Germany     10               32                32             47.8%
# 6   Greece      5                8                18             30.7%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5            15.6%                          80             2              1
# 6            19.2%                          32             1              1
#
#    Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                     0  ...          10                 62.6%         63
# 6                     1  ...          13                 65.1%         67
#
#   Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5             49        12             4          0       15        15
# 6             48        12             9          1       12        12
#
#    Players Used
# 5            17
# 6            20
#
# [2 rows x 35 columns]

# %%
#step 12 Select the first 7 columns
first_7_columns = euro12.iloc[:, :7]
print(first_7_columns)
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
#Step 13. Select all columns except the last 3
all_except_last_3_columns = euro12.iloc[:, :-3]
print(all_except_last_3_columns)
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
#Step 14. Present only the Shooting Accuracy from England, Italy and Russia
shooting_accuracy_selected_teams = euro12[euro12['Team'].isin(['England', 'Italy', 'Russia'])][['Team', 'Shooting Accuracy']]
print(tabulate(shooting_accuracy_selected_teams, headers='keys', tablefmt='pretty'))
# Out:
# +----+---------+-------------------+
# |    |  Team   | Shooting Accuracy |
# +----+---------+-------------------+
# | 3  | England |       50.0%       |
# | 7  |  Italy  |       43.0%       |
# | 12 | Russia  |       22.5%       |
# +----+---------+-------------------+

# %% [markdown]
# # Question 3

# %%
import pandas as pd
import numpy as np

random_series_1 = pd.Series(np.random.randint(1, 5, size=100))
random_series_2 = pd.Series(np.random.randint(1, 4, size=100))  
random_series_3 = pd.Series(np.random.randint(10000, 30001, size=100))  
data = pd.concat([random_series_1, random_series_2, random_series_3], axis=1)
data.columns = ['bedrs', 'bathrs', 'price_sqr_meter']
bigcolumn = pd.DataFrame(pd.concat([random_series_1, random_series_2, random_series_3], axis=0))

bigcolumn.reset_index(drop=True, inplace=True)
print(data)
print('\nbigcolumn:')
print(bigcolumn)
# Out:
#     bedrs  bathrs  price_sqr_meter
# 0       3       2            26987
# 1       4       3            29776
# 2       1       1            16867
# 3       1       1            26801
# 4       4       3            22371
# ..    ...     ...              ...
# 95      3       1            11037
# 96      2       2            26768
# 97      2       1            15822
# 98      2       2            16803
# 99      1       3            27280
#
# [100 rows x 3 columns]
#
# bigcolumn:
#          0
# 0        3
# 1        4
# 2        1
# 3        1
# 4        4
# ..     ...
# 295  11037
# 296  26768
# 297  15822
# 298  16803
# 299  27280
#
# [300 rows x 1 columns]

# %% [markdown]
# # Question 4

# %%
import pandas as pd

# Step 2: Import the dataset
url = "https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/06_Stats/Wind_Stats/wind.data"
data = pd.read_csv(url, sep='\s+', parse_dates=[[0, 1, 2]])

# Step 4: Fix the year 2061
def fix_year(year):
    if year.year > 1989:
        return year - pd.DateOffset(years=100)
    return year

data['Yr_Mo_Dy'] = data['Yr_Mo_Dy'].apply(fix_year)

# Step 5: Set the right dates as the index
data.set_index('Yr_Mo_Dy', inplace=True)

# Step 6: Count missing values for each location
missing_values_per_location = data.isnull().sum()

# Step 7: Count non-missing values in total
total_non_missing_values = data.notnull().sum().sum()

# Step 8: Calculate the mean windspeeds over all the locations and times
mean_windspeed = data.mean().mean()

# Step 9: Calculate statistics for each location
loc_stats = data.groupby(data.index.to_period('A')).describe()

# Step 10: Calculate statistics for each day
day_stats = data.resample('D').agg(['min', 'max', 'mean', 'std'])

# Step 11: Average windspeed in January for each location
january_avg_per_location = data.resample('M').mean()
january_avg_per_location = january_avg_per_location[january_avg_per_location.index.month == 1]

# Step 12: Downsample to yearly frequency
yearly_data = data.resample('A').mean()

# Step 13: Downsample to monthly frequency
monthly_data = data.resample('M').mean()

# Step 14: Downsample to weekly frequency
weekly_data = data.resample('W-MON').mean()  # Assume the first week starts on Monday, January 2, 1961

# Step 15: Calculate statistics for each week (first 52 weeks)
weekly_stats = weekly_data.head(52).agg(['min', 'max', 'mean', 'std'])

print("Missing Values:")
print(missing_values)
print("\nNon-Missing Count:")
print(non_missing_count)
print("\nMean Windspeed over all locations and times:")
print(mean_windspeed)
print("\nLocation Statistics:")
print(loc_stats)
print("\nDay Statistics:")
print(day_stats)
print("\nAverage Windspeed in January:")
print(january_avg_per_location)
print("\nYearly Frequency:")
print(yearly_data)
print("\nMonthly Frequency:")
print(monthly_data)
print("\nWeekly Frequency for the first 52 weeks:")
print(weekly_stats)
# Out:
# Missing Values:
# RPT    6
# VAL    3
# ROS    2
# KIL    5
# SHA    2
# BIR    0
# DUB    3
# CLA    2
# MUL    3
# CLO    1
# BEL    0
# MAL    4
# dtype: int64
#
# Non-Missing Count:
# 78857
#
# Mean Windspeed over all locations and times:
# 10.227982360836938
#
# Location Statistics:
#             RPT                                                          \
#           count       mean       std   min   25%    50%      75%    max
# Yr_Mo_Dy
# 1961      360.0  12.299583  5.303744  2.88  8.49  11.54  15.8100  28.75
# 1962      364.0  12.246923  6.145351  0.67  7.67  11.44  15.1725  35.80
# 1963      365.0  12.813452  6.052849  1.29  8.00  12.17  16.5000  32.96
# 1964      366.0  12.363661  5.314818  1.87  8.46  11.54  15.8300  33.34
# 1965      365.0  12.451370  5.471860  2.79  8.46  11.42  15.8300  32.17
# 1966      365.0  13.461973  5.776757  1.79  9.08  12.71  17.2100  34.37
# 1967      365.0  12.737151  5.716495  2.75  8.33  12.38  16.7500  30.09
# ...

# %% [markdown]
# # Question 5

# %%
# Step 1: Import the necessary libraries
import pandas as pd
from tabulate import tabulate

# Step 2: Import the dataset from the provided address
url = "https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv"
chipo = pd.read_csv(url, sep='\t')

# Step 3: Assign it to a variable called chipo

# Step 4: See the first 10 entries
print(tabulate(chipo.head(10), headers='keys', tablefmt='grid'))

# Step 5: Number of observations in the dataset
num_observations = len(chipo)
print("Number of observations:", num_observations)

# Step 6: Number of columns in the dataset
num_columns = chipo.shape[1]
print("Number of columns:", num_columns)

# Step 7: Print the name of all the columns
print("Columns:", chipo.columns.tolist())

# Step 8: How the dataset is indexed
print("Index:", chipo.index)

# Step 9: Most-ordered item
most_ordered_item = chipo['item_name'].value_counts().idxmax()
print("Most-ordered item:", most_ordered_item)

# Step 10: Quantity of the most-ordered item
most_ordered_item_quantity = chipo[chipo['item_name'] == most_ordered_item]['quantity'].sum()
print("Quantity of most-ordered item:", most_ordered_item_quantity)

# Step 11: Most ordered item in the choice_description column
most_ordered_choice = chipo['choice_description'].value_counts().idxmax()
print("Most-ordered choice:", most_ordered_choice)

# Step 12: Total items ordered
total_items_ordered = chipo['quantity'].sum()
print("Total items ordered:", total_items_ordered)

# Step 13:
# Turn the item price into a float
chipo['item_price'] = chipo['item_price'].apply(lambda x: float(x[1:]))

# Check the item price type
print("Item price type:", chipo['item_price'].dtype)

# Step 14: Revenue for the period in the dataset
revenue = (chipo['quantity'] * chipo['item_price']).sum()
print("Total revenue:", revenue)

# Step 15: Number of orders made
num_orders = chipo['order_id'].nunique()
print("Number of orders:", num_orders)

# Step 16: Average revenue amount per order
avg_revenue_per_order = revenue / num_orders
print("Average revenue per order:", avg_revenue_per_order)

# Step 17: Number of different items sold
num_unique_items = chipo['item_name'].nunique()
print("Number of different items sold:", num_unique_items)
# Out:
# +----+------------+------------+---------------------------------------+--------------------------------------------------------------------------------------------------------------------+--------------+
# |    |   order_id |   quantity | item_name                             | choice_description                                                                                                 | item_price   |
# +====+============+============+=======================================+====================================================================================================================+==============+
# |  0 |          1 |          1 | Chips and Fresh Tomato Salsa          | nan                                                                                                                | $2.39        |
# ...

# %% [markdown]
# # Question 6

# %%
import pandas as pd
import matplotlib.pyplot as plt

file_path = "/Users/rajvikchavda/Downloads/us-marriages-divorces-1867-2014.csv"
data = pd.read_csv(file_path)
plt.figure(figsize=(10, 6))
marriage_color = 'blue'
divorce_color = 'red'
plt.plot(data['Year'], data['Marriages_per_1000'], label='Marriages per 1000', color=marriage_color)
plt.plot(data['Year'], data['Divorces_per_1000'], label='Divorces per 1000', color=divorce_color)

plt.xlabel('Year')
plt.ylabel('Number per 1000')
plt.title('Number of Marriages and Divorces per Capita in the U.S. (1867-2014)')
plt.legend()

plt.grid(True)
plt.tight_layout()

plt.show()

# %% [markdown]
# # Question 7

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Step 1: Load the dataset
file_path = r"/Users/rajvikchavda/Downloads/us-marriages-divorces-1867-2014.csv"
data = pd.read_csv(file_path)
selected_years = [1900, 1950, 2000]
filtered_data = data[data['Year'].isin(selected_years)]
plt.figure(figsize=(10, 6))
bar_width = 4
offset = 2
marriage_color = 'blue'
divorce_color = 'red'
plt.bar(filtered_data['Year'] - offset, filtered_data['Marriages_per_1000'], width=bar_width, label='Marriages per 1000', color=marriage_color)
plt.bar(filtered_data['Year'] + offset, filtered_data['Divorces_per_1000'], width=bar_width, label='Divorces per 1000', color=divorce_color)

plt.title("Comparison of Marriages and Divorces per Capita in the U.S. Years 1900, 1950 and 2000.")
plt.xlabel("Year")
plt.ylabel("Rate per 1000")
plt.xticks(filtered_data['Year'], selected_years)
plt.legend()
plt.grid(axis='y')
plt.show()

# %% [markdown]
# # Question 8

# %%
import pandas as pd
import matplotlib.pyplot as plt
file_path = "/Users/rajvikchavda/Downloads/actor_kill_counts.csv"
data = pd.read_csv(file_path)
sorted_data = data.sort_values(by='Count', ascending=False)
plt.figure(figsize=(10, 6))
custom_colors = ['blue' if count > 50 else 'red' for count in sorted_data['Count']]

bars = plt.barh(sorted_data['Actor'], sorted_data['Count'], color=custom_colors)

plt.title("Deadliest Actors in Hollywood")
plt.xlabel("Kill Count")
plt.ylabel("Actor")
plt.grid(axis='x')
for bar, value in zip(bars, sorted_data['Count']):
    plt.text(value + 1, bar.get_y() + bar.get_height() / 2, str(value), va='center', color='black', fontsize=10)

plt.show()

# %% [markdown]
# # Question 9

# %%
import pandas as pd
import matplotlib.pyplot as plt

file_path = "/Users/rajvikchavda/Downloads/roman-emperor-reigns.csv"
data = pd.read_csv(file_path)
total_emperors = len(data)
assassinated_emperors = len(data[data['Cause_of_Death'] == 'Assassinated'])
not_assassinated_emperors = total_emperors - assassinated_emperors

labels = ['Assassinated', 'Not Assassinated']
sizes = [assassinated_emperors, not_assassinated_emperors]
colors = ['red', 'blue']
explode = (0.1, 0)  

plt.figure(figsize=(8, 8))
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=140)
plt.title("Fraction of Roman Emperors Assassinated")

plt.axis('equal')

plt.show()

# %% [markdown]
# # Question 10

# %%
import pandas as pd
import matplotlib.pyplot as plt

file_path = "/Users/rajvikchavda/Downloads/arcade-revenue-vs-cs-doctorates.csv"
data = pd.read_csv(file_path)

filtered_data = data[(data['Year'] >= 2000) & (data['Year'] <= 2009)]

plt.figure(figsize=(10, 6))
plt.scatter(filtered_data['Total Arcade Revenue (billions)'], filtered_data['Computer Science Doctorates Awarded (US)'], c=filtered_data['Year'], cmap='plasma')

plt.title("Relationship between Arcade Revenue and Computer Science PhDs (2000-2009)")
plt.xlabel("Total Arcade Revenue (billions)")
plt.ylabel("Computer Science Doctorates Awarded (US)")
plt.colorbar(label='Year')

plt.grid(linestyle='--', linewidth=0.7)

plt.show()
